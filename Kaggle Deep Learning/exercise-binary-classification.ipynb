# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([layers.BatchNormalization(input_shape=input_shape),
                        layers.Dense(256,activation='relu'),
                        layers.BatchNormalization(),
                        layers.Dropout(0.3),
                        layers.Dense(256,activation='relu'),
                        layers.BatchNormalization(),
                        layers.Dropout(0.3),
                        layers.Dense(1,activation='sigmoid')])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
____
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['binary_accuracy'])
# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 14ms/step - loss: 0.5363 - binary_accuracy: 0.7393 - val_loss: 0.4319 - val_binary_accuracy: 0.7963
# Epoch 2/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4273 - binary_accuracy: 0.7991 - val_loss: 0.4052 - val_binary_accuracy: 0.8073
# Epoch 3/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4090 - binary_accuracy: 0.8060 - val_loss: 0.3949 - val_binary_accuracy: 0.8181
# Epoch 4/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4039 - binary_accuracy: 0.8106 - val_loss: 0.3916 - val_binary_accuracy: 0.8197
# Epoch 5/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3958 - binary_accuracy: 0.8141 - val_loss: 0.3870 - val_binary_accuracy: 0.8222
# Epoch 6/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3924 - binary_accuracy: 0.8154 - val_loss: 0.3855 - val_binary_accuracy: 0.8242
# Epoch 7/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3876 - binary_accuracy: 0.8199 - val_loss: 0.3807 - val_binary_accuracy: 0.8278
# Epoch 8/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3851 - binary_accuracy: 0.8201 - val_loss: 0.3772 - val_binary_accuracy: 0.8297
# Epoch 9/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3783 - binary_accuracy: 0.8239 - val_loss: 0.3763 - val_binary_accuracy: 0.8304
# Epoch 10/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3736 - binary_accuracy: 0.8279 - val_loss: 0.3730 - val_binary_accuracy: 0.8303
# Epoch 11/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3772 - binary_accuracy: 0.8250 - val_loss: 0.3717 - val_binary_accuracy: 0.8321
# Epoch 12/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3692 - binary_accuracy: 0.8294 - val_loss: 0.3690 - val_binary_accuracy: 0.8320
# Epoch 13/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3703 - binary_accuracy: 0.8269 - val_loss: 0.3688 - val_binary_accuracy: 0.8335
# Epoch 14/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3657 - binary_accuracy: 0.8302 - val_loss: 0.3675 - val_binary_accuracy: 0.8321
# Epoch 15/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3678 - binary_accuracy: 0.8312 - val_loss: 0.3636 - val_binary_accuracy: 0.8346
# Epoch 16/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3624 - binary_accuracy: 0.8331 - val_loss: 0.3636 - val_binary_accuracy: 0.8346
# Epoch 17/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3637 - binary_accuracy: 0.8315 - val_loss: 0.3632 - val_binary_accuracy: 0.8357
# Epoch 18/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3603 - binary_accuracy: 0.8328 - val_loss: 0.3643 - val_binary_accuracy: 0.8345
# Epoch 19/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3597 - binary_accuracy: 0.8350 - val_loss: 0.3617 - val_binary_accuracy: 0.8367
# Epoch 20/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3620 - binary_accuracy: 0.8315 - val_loss: 0.3593 - val_binary_accuracy: 0.8358
# Epoch 21/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3574 - binary_accuracy: 0.8343 - val_loss: 0.3582 - val_binary_accuracy: 0.8376
# Epoch 22/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3544 - binary_accuracy: 0.8352 - val_loss: 0.3576 - val_binary_accuracy: 0.8386
# Epoch 23/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3529 - binary_accuracy: 0.8362 - val_loss: 0.3585 - val_binary_accuracy: 0.8362
# Epoch 24/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3549 - binary_accuracy: 0.8355 - val_loss: 0.3579 - val_binary_accuracy: 0.8364
# Epoch 25/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3542 - binary_accuracy: 0.8362 - val_loss: 0.3564 - val_binary_accuracy: 0.8395
# Epoch 26/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3514 - binary_accuracy: 0.8362 - val_loss: 0.3565 - val_binary_accuracy: 0.8380
# Epoch 27/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3507 - binary_accuracy: 0.8364 - val_loss: 0.3548 - val_binary_accuracy: 0.8375
# Epoch 28/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3479 - binary_accuracy: 0.8402 - val_loss: 0.3538 - val_binary_accuracy: 0.8410
# Epoch 29/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3462 - binary_accuracy: 0.8393 - val_loss: 0.3548 - val_binary_accuracy: 0.8399
# Epoch 30/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3482 - binary_accuracy: 0.8396 - val_loss: 0.3550 - val_binary_accuracy: 0.8385
# Epoch 31/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3430 - binary_accuracy: 0.8409 - val_loss: 0.3540 - val_binary_accuracy: 0.8387
# Epoch 32/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3444 - binary_accuracy: 0.8416 - val_loss: 0.3533 - val_binary_accuracy: 0.8392
# Epoch 33/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3421 - binary_accuracy: 0.8423 - val_loss: 0.3534 - val_binary_accuracy: 0.8411
# Epoch 34/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3427 - binary_accuracy: 0.8418 - val_loss: 0.3526 - val_binary_accuracy: 0.8400
# Epoch 35/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3441 - binary_accuracy: 0.8415 - val_loss: 0.3521 - val_binary_accuracy: 0.8401
# Epoch 36/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3398 - binary_accuracy: 0.8420 - val_loss: 0.3526 - val_binary_accuracy: 0.8403
# Epoch 37/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3426 - binary_accuracy: 0.8417 - val_loss: 0.3511 - val_binary_accuracy: 0.8407
# Epoch 38/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3413 - binary_accuracy: 0.8408 - val_loss: 0.3544 - val_binary_accuracy: 0.8399
# Epoch 39/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3359 - binary_accuracy: 0.8446 - val_loss: 0.3506 - val_binary_accuracy: 0.8410
# Epoch 40/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3351 - binary_accuracy: 0.8466 - val_loss: 0.3500 - val_binary_accuracy: 0.8414
# Epoch 41/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3342 - binary_accuracy: 0.8456 - val_loss: 0.3520 - val_binary_accuracy: 0.8422
# Epoch 42/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3365 - binary_accuracy: 0.8440 - val_loss: 0.3525 - val_binary_accuracy: 0.8400
# Epoch 43/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3363 - binary_accuracy: 0.8442 - val_loss: 0.3500 - val_binary_accuracy: 0.8420
# Epoch 44/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3347 - binary_accuracy: 0.8463 - val_loss: 0.3481 - val_binary_accuracy: 0.8435
# Epoch 45/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3380 - binary_accuracy: 0.8435 - val_loss: 0.3504 - val_binary_accuracy: 0.8422
# Epoch 46/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3332 - binary_accuracy: 0.8451 - val_loss: 0.3489 - val_binary_accuracy: 0.8438
# Epoch 47/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3328 - binary_accuracy: 0.8458 - val_loss: 0.3495 - val_binary_accuracy: 0.8432
# Epoch 48/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3299 - binary_accuracy: 0.8476 - val_loss: 0.3502 - val_binary_accuracy: 0.8409
# Epoch 49/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3308 - binary_accuracy: 0.8473 - val_loss: 0.3482 - val_binary_accuracy: 0.8420
# <AxesSubplot:title={'center':'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/191966) to chat with other Learners.*
