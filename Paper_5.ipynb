# %% [markdown]
# <a href="https://colab.research.google.com/github/San-dye/BCS-Paper-5/blob/main/Paper_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pip
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/47/ca/f0d790b6e18b3a6f3bd5e80c2ee4edbb5807286c21cdd0862ca933f751dd/pip-21.1.3-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.6MB 5.0MB/s
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-21.1.3

# %%
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# %%
! git clone https://github.com/chuckcho/youtube-8m.git
# Out:
# Cloning into 'youtube-8m'...
# remote: Enumerating objects: 691, done.
# remote: Total 691 (delta 0), reused 0 (delta 0), pack-reused 691
# Receiving objects: 100% (691/691), 217.82 KiB | 2.20 MiB/s, done.
# Resolving deltas: 100% (437/437), done.

# %%
import sys
print(sys.path)
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %%
# %ls
# Out:
# sample_data/  youtube-8m/

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
_URL = 'https://www.rocq.inria.fr/cluster-willow/amiech/pretrainedmodel.zip'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import networkx as nx
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS
import tensorflow as tf
from IPython.display import YouTubeVideo
plt.style.use('ggplot')

# %%
import tensorflow.compat.v1 as tf

# %%
! git clone https://github.com/antoine77340/Youtube-8M-WILLOW.git
# Out:
# Cloning into 'Youtube-8M-WILLOW'...
# remote: Enumerating objects: 119, done.
# remote: Total 119 (delta 0), reused 0 (delta 0), pack-reused 119
# Receiving objects: 100% (119/119), 58.25 KiB | 14.56 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# %ls
# Out:
# features/  sample_data/  Youtube-8M-WILLOW/

# %%
cd Youtube-8M-WILLOW/
# Out:
# /content/Youtube-8M-WILLOW

# %%
# %ls
# Out:
# cd/  clone/  git/  https:/  sample_data/  youtube-8m/

# %%
cd ..
# Out:
# /

# %%
! git clone https://github.com/antoine77340/LOUPE.git
# Out:
# Cloning into 'LOUPE'...
# remote: Enumerating objects: 68, done.
# remote: Total 68 (delta 0), reused 0 (delta 0), pack-reused 68
# Unpacking objects: 100% (68/68), done.

# %%
# %ls
# Out:
# cd/  clone/  git/  https:/  LOUPE/  sample_data/  youtube-8m/

# %%
cd LOUPE
# Out:
# /LOUPE

# %%
# %ls
# Out:
# cd/  clone/  git/  https:/  LOUPE/  sample_data/  youtube-8m/

# %%
import numpy as np

# %%
cd ..
# Out:
# /

# %%
cd content
# Out:
# /content

# %%
# %ls
# Out:
# features/  sample_data/  Youtube-8M-WILLOW/

# %%
! git clone https://github.com/antoine77340/LOUPE.git
# Out:
# Cloning into 'LOUPE'...
# remote: Enumerating objects: 68, done.
# remote: Total 68 (delta 0), reused 0 (delta 0), pack-reused 68
# Unpacking objects: 100% (68/68), done.

# %%
# %ls
# Out:
# features/  LOUPE/  sample_data/  Youtube-8M-WILLOW/

# %%
cd LOUPE
# Out:
# /content/LOUPE

# %%
# %ls
# Out:
# LICENSE  loupe.py  README.md

# %%
pip install --upgrade tf_slim
# Out:
# Collecting tf_slim
#   Downloading https://files.pythonhosted.org/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl (352kB)
#      |████████████████████████████████| 358kB 20.0MB/s
# Requirement already satisfied, skipping upgrade: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf_slim) (0.12.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)
# Installing collected packages: tf-slim
# Successfully installed tf-slim-1.1.0

# %%
import tf_slim as slim

# %%
! pip install git+https://github.com/google-research/tf-slim.git
# Out:
# Collecting git+https://github.com/google-research/tf-slim.git
#   Cloning https://github.com/google-research/tf-slim.git to /tmp/pip-req-build-pqqt7zex
#   Running command git clone -q https://github.com/google-research/tf-slim.git /tmp/pip-req-build-pqqt7zex
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf-slim==1.2.0) (0.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.2.2->tf-slim==1.2.0) (1.15.0)
# Building wheels for collected packages: tf-slim
#   Building wheel for tf-slim (setup.py) ... done
#   Created wheel for tf-slim: filename=tf_slim-1.2.0-cp37-none-any.whl size=361059 sha256=eff9a8c9f7a7dd991f38c49642a76c41e390044baae421b71d59b15bb2df2da7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xbs1psmc/wheels/2b/ed/a5/aa04c89c01296fa98943d20f39c34b7d10d8671506823ba42e
# Successfully built tf-slim
# Installing collected packages: tf-slim
# Successfully installed tf-slim-1.2.0

# %%
! pip install six
# Out:
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (1.15.0)

# %%
# !wget -c https://github.com/google/youtube-8m/blob/master/.github/workflows/pythonpackage.yml
# Out:
# --2021-07-08 19:28:07--  https://github.com/google/youtube-8m/blob/master/.github/workflows/pythonpackage.yml
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘pythonpackage.yml’
#
# pythonpackage.yml       [ <=>                ] 121.63K   666KB/s    in 0.2s
#
# 2021-07-08 19:28:07 (666 KB/s) - ‘pythonpackage.yml’ saved [124554]

# %%
import os
import sys
import tarfile
import numpy
from six.moves import urllib
import tensorflow as tf

INCEPTION_TF_GRAPH = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'
YT8M_PCA_MAT = 'http://data.yt8m.org/yt8m_pca.tgz'
MODEL_DIR = os.path.join(os.getenv('HOME'), 'yt8m')

# %%
# %mkdir -p /path/to/yt8m_files
# %cd /path/to/yt8m_files

# !wget http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz
# !wget http://data.yt8m.org/yt8m_pca.tgz

tar = 'zxvf inception-2015-12-05.tgz'
tar = 'zxvf yt8m_pca.tgz'
# Out:
# /path/to/yt8m_files
# --2021-07-08 21:11:18--  http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.2.128, 2607:f8b0:4023:c0d::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.2.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88931400 (85M) [application/x-compressed-tar]
# Saving to: ‘inception-2015-12-05.tgz’
#
# inception-2015-12-0 100%[===================>]  84.81M  61.0MB/s    in 1.4s
#
# 2021-07-08 21:11:20 (61.0 MB/s) - ‘inception-2015-12-05.tgz’ saved [88931400/88931400]
#
# --2021-07-08 21:11:20--  http://data.yt8m.org/yt8m_pca.tgz
# Resolving data.yt8m.org (data.yt8m.org)... 142.251.2.128, 2607:f8b0:4023:c0d::80
# Connecting to data.yt8m.org (data.yt8m.org)|142.251.2.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15654272 (15M) [application/x-tar]
# Saving to: ‘yt8m_pca.tgz’
#
# yt8m_pca.tgz        100%[===================>]  14.93M  52.3MB/s    in 0.3s
#
# 2021-07-08 21:11:21 (52.3 MB/s) - ‘yt8m_pca.tgz’ saved [15654272/15654272]

# %%
# !wget https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=frame-sample.zip
# Out:
# --2021-07-09 10:52:31--  https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=frame-sample.zip
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data?select=frame-sample.zip’
#
# data?select=frame-s     [ <=>                ]  86.54K   562KB/s    in 0.2s
#
# 2021-07-09 10:52:31 (562 KB/s) - ‘data?select=frame-sample.zip’ saved [88616]

# %%
# !wget https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=vocabulary.csv
# Out:
# --2021-07-09 11:14:26--  https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=vocabulary.csv
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data?select=vocabulary.csv’
#
# data?select=vocabul     [ <=>                ]  86.54K   504KB/s    in 0.2s
#
# 2021-07-09 11:14:27 (504 KB/s) - ‘data?select=vocabulary.csv’ saved [88614]

# %%
# %ls
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# 'data?select=frame-sample.zip'   drive/   gdrive/
# 'data?select=vocabulary.csv'     frame/   sample_data/

# %%
# !unzip vocabulary
# Out:
# unzip:  cannot find or open vocabulary, vocabulary.zip or vocabulary.ZIP.

# %%
# %ls
# Out:
# 'data?select=frame-sample.zip'   drive/   sample_data/

# %%
# !unzip frame-sample
# Out:
# unzip:  cannot find or open frame-sample, frame-sample.zip or frame-sample.ZIP.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/My\ Drive/frame-sample.zip
# Out:
# Archive:  gdrive/My Drive/frame-sample.zip
# replace frame/train01.tfrecord? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: frame/train01.tfrecord
# replace frame/train00.tfrecord? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: frame/train00.tfrecord

# %%
# !unzip gdrive/My\ Drive/validate-sample.zip
# Out:
# unzip:  cannot find or open gdrive/My Drive/validate-sample.zip, gdrive/My Drive/validate-sample.zip.zip or gdrive/My Drive/validate-sample.zip.ZIP.

# %%
# !unzip gdrive/My\ Drive/vocabulary.csv
# Out:
# unzip:  cannot find or open gdrive/My Drive/vocabulary.csv, gdrive/My Drive/vocabulary.csv.zip or gdrive/My Drive/vocabulary.csv.ZIP.

# %%
# !wget https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=validate-sample.zip
# Out:
# --2021-07-09 11:31:39--  https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=validate-sample.zip
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data?select=validate-sample.zip.2’
#
# data?select=validat     [ <=>                ]  86.54K   560KB/s    in 0.2s
#
# 2021-07-09 11:31:39 (560 KB/s) - ‘data?select=validate-sample.zip.2’ saved [88619]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %ls
# Out:
# ls: cannot access 'gdrive': Transport endpoint is not connected
# 'data?select=frame-sample.zip'       'data?select=vocabulary.csv'
# 'data?select=sample_submission.csv'   drive/
# 'data?select=validate-sample.zip'     frame/
# 'data?select=validate-sample.zip.1'   gdrive/
# 'data?select=validate-sample.zip.2'   sample_data/

# %%
# !unzip gdrive/My\ Drive/frame-sample.zip > /dev/null
# Out:
# replace frame/train01.tfrecord? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace frame/train00.tfrecord? [y]es, [n]o, [A]ll, [N]one, [r]ename: y

# %%
# !unzip gdrive/My\ Drive/frame-sample.zip
# Out:
# unzip:  cannot find or open gdrive/My Drive/frame-sample.zip, gdrive/My Drive/frame-sample.zip.zip or gdrive/My Drive/frame-sample.zip.ZIP.

# %%
import os
print(os.listdir("../bin"))
# Out:
# ['mount', 'domainname', 'rmdir', 'readlink', 'false', 'nisdomainname', 'mknod', 'zgrep', 'uncompress', 'cp', 'egrep', 'mktemp', 'dir', 'mountpoint', 'zless', 'pwd', 'tar', 'hostname', 'date', 'bzip2', 'sh.distrib', 'gzexe', 'true', 'dnsdomainname', 'bash', 'gunzip', 'zcat', 'ypdomainname', 'login', 'rbash', 'bunzip2', 'mkdir', 'sh', 'lsblk', 'rm', 'chmod', 'bzless', 'znew', 'sleep', 'stty', 'tempfile', 'mv', 'sed', 'zdiff', 'zegrep', 'ln', 'bzcat', 'bzexe', 'dmesg', 'zcmp', 'bzegrep', 'pidof', 'bzip2recover', 'echo', 'findmnt', 'zforce', 'umount', 'bzdiff', 'ls', 'chgrp', 'df', 'more', 'dash', 'bzgrep', 'grep', 'chown', 'fgrep', 'wdctl', 'touch', 'bzcmp', 'vdir', 'kill', 'gzip', 'bzfgrep', 'bzmore', 'sync', 'run-parts', 'uname', 'zfgrep', 'dd', 'ps', 'su', 'cat', 'zmore', 'which', 'systemd-machine-id-setup', 'systemd-tty-ask-password-agent', 'systemd', 'loginctl', 'journalctl', 'networkctl', 'lsmod', 'udevadm', 'systemd-hwdb', 'systemd-inhibit', 'fusermount', 'systemd-ask-password', 'systemd-escape', 'lesspipe', 'fuser', 'kmod', 'ulockmgr_server', 'systemd-sysusers', 'systemd-tmpfiles', 'lessecho', 'lesskey', 'lessfile', 'systemd-notify', 'less', 'systemctl']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
frame_lvl_record = "../frame-sample/frame/train00.tfrecord"

# %%
import matplotlib.pyplot as plt
import csv
import io
import tensorflow as tf
from IPython.display import YouTubeVideo
plt.style.use('ggplot')

# %%
import os
print(os.listdir("../content"))
# Out:
# ['.config', 'frame', 'data?select=vocabulary.csv', 'gdrive', 'data?select=sample_submission.csv', 'drive', 'data?select=validate-sample.zip.1', 'data?select=frame-sample.zip', 'data?select=validate-sample.zip', 'data?select=validate-sample.zip.2', 'sample_data']

# %%
frame_lvl_record = "../content/frame-sample/frame/train00.tfrecord"

# %%
print(os.listdir("../home"))
# Out:
# []

# %%
# !wget https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=sample_submission.csv
# Out:
# --2021-07-09 11:30:44--  https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=sample_submission.csv
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data?select=sample_submission.csv’
#
# data?select=sample_     [ <=>                ]  86.54K   561KB/s    in 0.2s
#
# 2021-07-09 11:30:45 (561 KB/s) - ‘data?select=sample_submission.csv’ saved [88621]

# %%
# !wget https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data
# Out:
# --2021-07-09 14:50:48--  https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data’
#
# data                    [  <=>               ]  86.52K   350KB/s    in 0.2s
#
# 2021-07-09 14:50:49 (350 KB/s) - ‘data’ saved [88592]

# %%
# !wget https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=validate-sample.zip
# Out:
# --2021-07-09 15:39:25--  https://www.kaggle.com/jagannathrk/analysis-youtube8m-2019/data?select=validate-sample.zip
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data?select=validate-sample.zip’
#
# data?select=validat     [  <=>               ]  86.54K   348KB/s    in 0.2s
#
# 2021-07-09 15:39:26 (348 KB/s) - ‘data?select=validate-sample.zip’ saved [88619]

# %%
# %ls
# Out:
#  data  'data?select=validate-sample.zip'   sample_data/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip validate-sample.zip
# Out:
# unzip:  cannot find or open validate-sample.zip, validate-sample.zip.zip or validate-sample.zip.ZIP.

# %%
# %ls
# Out:
# data  sample_data/

# %%
# %ls
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# 'data?select=frame-sample.zip'        drive/
# 'data?select=sample_submission.csv'   frame/
# 'data?select=validate-sample.zip'     gdrive/
# 'data?select=validate-sample.zip.1'   sample_data/
# 'data?select=vocabulary.csv'

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/frame-sample.zip
# Out:
# Archive:  /content/drive/MyDrive/frame-sample.zip
#    creating: frame/
#   inflating: frame/train01.tfrecord
#   inflating: frame/train00.tfrecord

# %%
# !unzip /content/drive/MyDrive/validate-sample.zip
# Out:
# Archive:  /content/drive/MyDrive/validate-sample.zip
#    creating: validate/
#   inflating: validate/validate01.tfrecord
#   inflating: validate/validate00.tfrecord

# %%
import os
print(os.listdir("../content"))
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
frame_lvl_record = "../content/drive/MyDrive/frame/train00.tfrecord"

# %%
print(os.listdir("../content/drive/MyDrive"))
# Out:
# ['frame-sample.zip', 'validate-sample.zip', 'vocabulary.csv', 'sample_submission.csv']

# %%
import tensorflow as tf
import numpy as np
from IPython.display import YouTubeVideo

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np

# %%
vocab = pd.read_csv('../content/drive/MyDrive/vocabulary.csv')
print("we have {} unique labels in the dataset".format(len(vocab['Index'].unique())))
# Out:
# we have 1000 unique labels in the dataset

# %%
vocab.head
# Out:
# <bound method NDFrame.head of      Index  ...                                    WikiDescription
# 0        3  ...  A concert is a live music performance in front...
# 1        7  ...  A car is a wheeled, self-powered motor vehicle...
# 2        8  ...  Dance is a performance art form consisting of ...
# 3       11  ...  Food is any substance consumed to provide nutr...
# 4       12  ...  Association football, more commonly known as f...
# ..     ...  ...                                                ...
# 995   1781  ...  A castle is a type of fortified structure buil...
# 996   1769  ...  A clutch is a mechanical device that engages a...
# 997   1805  ...  A school bus is a type of bus used for student...
# 998   1788  ...  Zero is a video game character present through...
# 999   1801  ...  The Siamese fighting fish, also sometimes coll...
#
# [1000 rows x 9 columns]>

# %%
vocab.shape
# Out:
# (1000, 9)

# %%
from collections import Counter

label_mapping =  vocab[['Index', 'Name']].set_index('Index', drop=True).to_dict()['Name']
print("we have {} unique labels in the dataset".format(len(vocab['Index'].unique())))
# Out:
# we have 1000 unique labels in the dataset

# %%
validate_record = "../input/validate-sample/validate/validate00.tfrecord"

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
! git clone --branch r1.13.0 --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 2927, done.
# remote: Counting objects: 100% (2927/2927), done.
# remote: Compressing objects: 100% (2428/2428), done.
# remote: Total 2927 (delta 504), reused 2113 (delta 424), pack-reused 0
# Receiving objects: 100% (2927/2927), 369.04 MiB | 27.10 MiB/s, done.
# Resolving deltas: 100% (504/504), done.
# Checking out files: 100% (2768/2768), done.

# %%
# !tf_upgrade_v2 -h
# Out:
# usage: tf_upgrade_v2 [-h] [--infile INPUT_FILE] [--outfile OUTPUT_FILE]
#                      [--intree INPUT_TREE] [--outtree OUTPUT_TREE]
#                      [--copyotherfiles COPY_OTHER_FILES] [--inplace]
#                      [--import_rename] [--reportfile REPORT_FILENAME]
#                      [--mode {DEFAULT,SAFETY}] [--print_all]
#
# Convert a TensorFlow Python file from 1.x to 2.0
#
# Simple usage:
#   tf_upgrade_v2.py --infile foo.py --outfile bar.py
#   tf_upgrade_v2.py --infile foo.ipynb --outfile bar.ipynb
#   tf_upgrade_v2.py --intree ~/code/old --outtree ~/code/new
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --infile INPUT_FILE   If converting a single file, the name of the file to
#                         convert
#   --outfile OUTPUT_FILE
#                         If converting a single file, the output filename.
#   --intree INPUT_TREE   If converting a whole tree of files, the directory to
#                         read from (relative or absolute).
#   --outtree OUTPUT_TREE
#                         If converting a whole tree of files, the output
#                         directory (relative or absolute).
#   --copyotherfiles COPY_OTHER_FILES
#                         If converting a whole tree of files, whether to copy
#                         the other files.
#   --inplace             If converting a set of files, whether to allow the
#                         conversion to be performed on the input files.
#   --import_rename       Whether to rename import to compact.v2 explicitly.
#   --reportfile REPORT_FILENAME
#                         The name of the file where the report log is
#                         stored.(default: report.txt)
#   --mode {DEFAULT,SAFETY}
#                         Upgrade script mode. Supported modes: DEFAULT: Perform
#                         only straightforward conversions to upgrade to 2.0. In
#                         more difficult cases, switch to use compat.v1. SAFETY:
#                         Keep 1.* code intact and import compat.v1 module.
#   --print_all           Print full log to stdout instead of just printing
#                         errors

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# !unzip /content/drive/MyDrive/label_name.csv.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/label_name.csv.zip, /content/drive/MyDrive/label_name.csv.zip.zip or /content/drive/MyDrive/label_name.csv.zip.ZIP.

# %%
# !unzip label_names.csv
# Out:
# unzip:  cannot find or open label_names.csv, label_names.csv.zip or label_names.csv.ZIP.

# %%
import tensorflow as tf
import numpy as np
from IPython.display import YouTubeVideo


video_lvl_record = "../input/video_level/train-1.tfrecord"
frame_lvl_record = "../input/frame_level/train-1.tfrecord"

# %%
# !wget https://www.kaggle.com/veerabhadrappa/youtube8m-explorer/data?select=label_names.csv.zip
# Out:
# --2021-07-10 20:53:01--  https://www.kaggle.com/veerabhadrappa/youtube8m-explorer/data?select=label_names.csv.zip
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data?select=label_names.csv.zip.1’
#
# data?select=label_n     [ <=>                ]  27.73K  --.-KB/s    in 0s
#
# 2021-07-10 20:53:01 (105 MB/s) - ‘data?select=label_names.csv.zip.1’ saved [28399]

# %%
sub = pd.read_csv('../content/drive/MyDrive/sample_submission.csv')
sub.head()
print ("submission style ...")
# Out:
# submission style ...

# %%
import os
print(os.listdir("../content/drive/MyDrive"))

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['frame-sample.zip', 'validate-sample.zip', 'vocabulary.csv', 'sample_submission.csv', 'label_names.csv.zip']

# %%
print(os.listdir("../content/drive/MyDrive"))
# Out:
# ['frame-sample.zip', 'validate-sample.zip', 'vocabulary.csv', 'sample_submission.csv', 'label_names.csv.zip']

# %%
# !unzip /content/drive/MyDrive/frame-sample.zip
# Out:
# Archive:  /content/drive/MyDrive/frame-sample.zip
#    creating: frame/
#   inflating: frame/train01.tfrecord
#   inflating: frame/train00.tfrecord

# %%
print(os.listdir("../content/frame"))
# Out:
# ['train00.tfrecord', 'train01.tfrecord']

# %%
# !unzip /content/drive/MyDrive/validate-sample.zip
# Out:
# Archive:  /content/drive/MyDrive/validate-sample.zip
#    creating: validate/
#   inflating: validate/validate01.tfrecord
#   inflating: validate/validate00.tfrecord

# %%
print(os.listdir("../content/validate"))
# Out:
# ['validate01.tfrecord', 'validate00.tfrecord']

# %%
frame_lvl_record = "../content/frame/train00.tfrecord"

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
vid_ids = []
labels = []

for example in tf.io.tf_record_iterator(frame_lvl_record):
    tf_example = tf.train.Example.FromString(example)
    vid_ids.append(tf_example.features.feature['id']
                   .bytes_list.value[0].decode(encoding='UTF-8'))
    labels.append(tf_example.features.feature['labels'].int64_list.value)
# Out:
# WARNING:tensorflow:From <ipython-input-34-5b7b3c3993f9>:4: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
print('Number of videos in this tfrecord: ',len(vid_ids))
print ('Number of labels in this tfrecord: ', len (labels))
print('Picking a youtube video id:',vid_ids[15])
# Out:
# Number of videos in this tfrecord:  1015
# Number of labels in this tfrecord:  1015
# Picking a youtube video id: FF00

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UzXQaOLQVCU')

# %%
# due to execution time, we're only going to read the first video

feat_rgb = []
feat_audio = []

for example in tf.python_io.tf_record_iterator(frame_lvl_record):  
    tf_seq_example = tf.train.SequenceExample.FromString(example)
    n_frames = len(tf_seq_example.feature_lists.feature_list['audio'].feature)
    sess = tf.InteractiveSession()
    rgb_frame = []
    audio_frame = []
    # iterate through frames
    for i in range(n_frames):
        rgb_frame.append(tf.cast(tf.decode_raw(
                tf_seq_example.feature_lists.feature_list['rgb']
                  .feature[i].bytes_list.value[0],tf.uint8)
                       ,tf.float32).eval())
        audio_frame.append(tf.cast(tf.decode_raw(
                tf_seq_example.feature_lists.feature_list['audio']
                  .feature[i].bytes_list.value[0],tf.uint8)
                       ,tf.float32).eval())
        
        
    sess.close()
    
    feat_audio.append(audio_frame)
    feat_rgb.append(rgb_frame)
    break

# %%
print('The first video has %d frames' %len(feat_rgb[0]))
# Out:
# The first video has 234 frames

# %%
vocabulary = pd.read_csv('../content/drive/MyDrive/vocabulary.csv')
vocabulary.head()
# Out:
#    Index  ...                                    WikiDescription
# 0      3  ...  A concert is a live music performance in front...
# 1      7  ...  A car is a wheeled, self-powered motor vehicle...
# 2      8  ...  Dance is a performance art form consisting of ...
# 3     11  ...  Food is any substance consumed to provide nutr...
# 4     12  ...  Association football, more commonly known as f...
#
# [5 rows x 9 columns]

# %%
vocabulary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Index             1000 non-null   int64
#  1   TrainVideoCount   1000 non-null   int64
#  2   KnowledgeGraphId  1000 non-null   object
#  3   Name              988 non-null    object
#  4   WikiUrl           988 non-null    object
#  5   Vertical1         1000 non-null   object
#  6   Vertical2         153 non-null    object
#  7   Vertical3         12 non-null     object
#  8   WikiDescription   988 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 70.4+ KB

# %%
from collections import Counter

label_mapping =  vocabulary[['Index', 'Name']].set_index('Index', drop=True).to_dict()['Name']
print("we have {} unique labels in the dataset".format(len(vocabulary['Index'].unique())))
# Out:
# we have 1000 unique labels in the dataset

# %%
n = 30 
top_n = Counter([item for sublist in labels for item in sublist]).most_common(n)
top_n_labels = [int(i[0]) for i in top_n]
top_n_label_names = [label_mapping[x] for x in top_n_labels if x in label_mapping] # filter out the labels that aren't in the 1,000 used for this competition
print(top_n_label_names)
# Out:
# ['Concert', 'Car', 'Association football', 'Food', 'Dance', 'Motorsport', 'Racing', 'Mobile phone', 'Smartphone', 'Cooking', 'Pet', 'Dish (food)', 'Drum kit']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

labels_count_dict = dict(top_n)
labels_count_df = pd.DataFrame.from_dict(labels_count_dict, orient='index').reset_index()
labels_count_df.columns = ['label', 'count']
labels_count_df['label'] = labels_count_df['label'].map(label_mapping, na_action='ignore')
TOP_labels = list(labels_count_df['label'])[:n]
fig, ax = plt.subplots(figsize=(10,7))
sns.barplot(y='label', x='count', data=labels_count_df)
plt.title('Top {} labels with sample count'.format(n))
# Out:
# Text(0.5, 1.0, 'Top 30 labels with sample count')

# %%
import networkx as nx
from itertools import combinations

G = nx.Graph()

G.clear()
for list_of_nodes in labels:
    filtered_nodes = set(list_of_nodes).intersection(set(top_n_labels) & 
                                                     set(vocabulary['Index'].unique()))  
    for node1,node2 in list(combinations(filtered_nodes,2)): 
        node1_name = label_mapping[node1]
        node2_name = label_mapping[node2]
        G.add_node(node1_name)
        G.add_node(node2_name)
        G.add_edge(node1_name, node2_name)

plt.figure(figsize=(9,9))
nx.draw_networkx(G, font_size="12")

# %%
plt.figure(figsize = (10,8))
vocabulary.groupby('Vertical1').TrainVideoCount.sum().plot(kind="bar")
plt.title("Average TrainVideoCount per vertical1")
plt.show()

plt.figure(figsize = (10,8))
vocabulary.groupby('Vertical1').Index.count().plot(kind="bar")
plt.title("Average number video per vertical1")
plt.show()

# %%
plt.figure(figsize = (10,8))
vocabulary.groupby('Vertical2').TrainVideoCount.sum().plot(kind="bar")
plt.title("Average TrainVideoCount per vertical2")
plt.show()

plt.figure(figsize = (10,8))
vocabulary.groupby('Vertical2').TrainVideoCount.count().plot(kind="bar")
plt.title("Average video number per vertical2")
plt.show()

# %%
plt.figure(figsize = (10,8))
vocabulary.groupby('Vertical3').TrainVideoCount.sum().plot(kind="bar")
plt.title("Average TrainVideoCount per vertical3")
plt.show()

plt.figure(figsize = (10,8))
vocabulary.groupby('Vertical3').TrainVideoCount.count().plot(kind="bar")
plt.title("Average video number per vertical3")
plt.show()

# %%
sns.lmplot(x='Index', y='TrainVideoCount', data=vocabulary , size=15)

# %%
vocabulary.groupby('Vertical1').corr()
# Out:
#                                             Index  TrainVideoCount
# Vertical1
# Arts & Entertainment    Index            1.000000        -0.335583
#                         TrainVideoCount -0.335583         1.000000
# Autos & Vehicles        Index            1.000000        -0.380617
#                         TrainVideoCount -0.380617         1.000000
# Beauty & Fitness        Index            1.000000        -0.687573
#                         TrainVideoCount -0.687573         1.000000
# Books & Literature      Index            1.000000        -1.000000
#                         TrainVideoCount -1.000000         1.000000
# Business & Industrial   Index            1.000000        -0.643655
#                         TrainVideoCount -0.643655         1.000000
# Computers & Electronics Index            1.000000        -0.676121
#                         TrainVideoCount -0.676121         1.000000
# Finance                 Index            1.000000        -1.000000
#                         TrainVideoCount -1.000000         1.000000
# Food & Drink            Index            1.000000        -0.399347
#                         TrainVideoCount -0.399347         1.000000
# Games                   Index            1.000000        -0.780424
#                         TrainVideoCount -0.780424         1.000000
# Health                  Index            1.000000        -0.994288
#                         TrainVideoCount -0.994288         1.000000
# Hobbies & Leisure       Index            1.000000        -0.646854
#                         TrainVideoCount -0.646854         1.000000
# Home & Garden           Index            1.000000        -0.679861
#                         TrainVideoCount -0.679861         1.000000
# Internet & Telecom      Index            1.000000        -0.756289
#                         TrainVideoCount -0.756289         1.000000
# Jobs & Education        Index            1.000000        -0.797151
#                         TrainVideoCount -0.797151         1.000000
# Law & Government        Index            1.000000        -0.908027
#                         TrainVideoCount -0.908027         1.000000
# News                    Index            1.000000        -0.999905
#                         TrainVideoCount -0.999905         1.000000
# People & Society        Index            1.000000        -0.966089
#                         TrainVideoCount -0.966089         1.000000
# Pets & Animals          Index            1.000000        -0.447703
#                         TrainVideoCount -0.447703         1.000000
# Real Estate             Index            1.000000        -0.910366
#                         TrainVideoCount -0.910366         1.000000
# Reference               Index            1.000000        -0.801549
#                         TrainVideoCount -0.801549         1.000000
# Science                 Index            1.000000        -0.825646
#                         TrainVideoCount -0.825646         1.000000
# Shopping                Index            1.000000        -0.800188
#                         TrainVideoCount -0.800188         1.000000
# Sports                  Index            1.000000        -0.454807
#                         TrainVideoCount -0.454807         1.000000
# Travel                  Index            1.000000        -0.831157
#                         TrainVideoCount -0.831157         1.000000

# %% [markdown]
# **WordCloud**

# %%
from wordcloud import WordCloud, STOPWORDS
plt.figure(figsize = (15,15))

stopwords = set(STOPWORDS)

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=1000,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(vocabulary['WikiDescription']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - description")
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f989efa5c10>

# %%
plt.figure(figsize = (15,15))

stopwords = set(STOPWORDS)

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=1000,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(vocabulary['Name']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Name")
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f989e4ef150>

# %%
plt.figure(figsize = (15,15))

stopwords = set(STOPWORDS)

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=1000,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(vocabulary['Vertical1']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Vertical1")
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f989e480e10>

# %%
plt.figure(figsize = (15,15))

stopwords = set(STOPWORDS)

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=1000,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(vocabulary['Vertical2']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Vertical2")
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f989cbef650>

# %% [markdown]
# **Vocabulary** **List**

# %%
import csv
with open('../content/drive/MyDrive/vocabulary.csv', 'r') as f:
  vocabularylist = list(csv.reader(f))

T1=[]

for l in vocabularylist:
    if l[5] != 'NaN' and l[6] !='NaN' and l[5] != '' and l[6] !='' and l[5] !=  l[6] :
        c1 = l[5]
        c2 = l[6]
        tuple = (c1, c2)
    if l[5] != 'NaN' and l[7] !='NaN' and l[5] != '' and l[7] !='' and l[5] !=  l[7] :
        c1 = l[5]
        c2 = l[7]
        tuple = (c1, c2)
    if l[6] != 'NaN' and l[7] !='NaN' and l[6] != '' and l[7] !='' and l[7] !=  l[6] :
        c1 = l[6]
        c2 = l[7]
        tuple = (c1, c2)
    T1.append(tuple)
    
edges = {k: T1.count(k) for k in set(T1)}
print ("List = ",len(edges), "elements")
edges
# Out:
# List =  60 elements
# {('Arts & Entertainment', 'Books & Literature'): 9,
#  ('Arts & Entertainment', 'Business & Industrial'): 35,
#  ('Arts & Entertainment', 'Games'): 21,
#  ('Arts & Entertainment', 'Hobbies & Leisure'): 7,
#  ('Arts & Entertainment', 'People & Society'): 22,
#  ('Arts & Entertainment', 'Reference'): 27,
#  ('Arts & Entertainment', 'Science'): 18,
#  ('Arts & Entertainment', 'Shopping'): 28,
#  ('Arts & Entertainment', 'Sports'): 21,
#  ('Autos & Vehicles', 'Business & Industrial'): 36,
#  ('Autos & Vehicles', 'Law & Government'): 19,
#  ('Autos & Vehicles', 'News'): 6,
#  ('Autos & Vehicles', 'People & Society'): 7,
#  ('Autos & Vehicles', 'Science'): 2,
#  ('Autos & Vehicles', 'Shopping'): 5,
#  ('Autos & Vehicles', 'Sports'): 28,
#  ('Autos & Vehicles', 'Travel'): 4,
#  ('Beauty & Fitness', 'Business & Industrial'): 12,
#  ('Beauty & Fitness', 'Hobbies & Leisure'): 7,
#  ('Beauty & Fitness', 'Home & Garden'): 9,
#  ('Beauty & Fitness', 'People & Society'): 2,
#  ('Beauty & Fitness', 'Shopping'): 7,
#  ('Books & Literature', 'People & Society'): 13,
#  ('Business & Industrial', 'Food & Drink'): 49,
#  ('Business & Industrial', 'Hobbies & Leisure'): 9,
#  ('Business & Industrial', 'Home & Garden'): 22,
#  ('Business & Industrial', 'Law & Government'): 5,
#  ('Business & Industrial', 'Science'): 19,
#  ('Business & Industrial', 'Shopping'): 21,
#  ('Business & Industrial', 'Sports'): 11,
#  ('Business & Industrial', 'Travel'): 13,
#  ('Computers & Electronics', 'Games'): 26,
#  ('Computers & Electronics', 'Internet & Telecom'): 105,
#  ('Computers & Electronics', 'News'): 18,
#  ('Food & Drink', 'Hobbies & Leisure'): 10,
#  ('Food & Drink', 'Home & Garden'): 2,
#  ('Food & Drink', 'News'): 5,
#  ('Food & Drink', 'Science'): 29,
#  ('Food & Drink', 'Travel'): 7,
#  ('Hobbies & Leisure', 'Home & Garden'): 2,
#  ('Hobbies & Leisure', 'Law & Government'): 5,
#  ('Hobbies & Leisure', 'Reference'): 15,
#  ('Hobbies & Leisure', 'Shopping'): 7,
#  ('Hobbies & Leisure', 'Sports'): 29,
#  ('Hobbies & Leisure', 'Travel'): 22,
#  ('Home & Garden', 'Real Estate'): 10,
#  ('Home & Garden', 'Science'): 1,
#  ('Law & Government', 'Arts & Entertainment'): 2,
#  ('News', 'Science'): 5,
#  ('News', 'Shopping'): 5,
#  ('People & Society', 'Reference'): 4,
#  ('People & Society', 'Shopping'): 2,
#  ('Pets & Animals', 'Science'): 116,
#  ('Reference', 'Travel'): 16,
#  ('Science', 'Shopping'): 4,
#  ('Science', 'Travel'): 6,
#  ('Shopping', 'Sports'): 10,
#  ('Sports', 'Hobbies & Leisure'): 21,
#  ('Travel', 'Reference'): 3,
#  ('Vertical2', 'Vertical3'): 20}

# %%
B = nx.DiGraph()
nodecolor=[]
for ed, weight in edges.items():
    if ed[0]!='Vertical2' and ed[0]!='Vertical3' and  ed[1]!='Vertical2' and ed[1]!='Vertical3':
        B.add_edge(ed[0], ed[1], weight=weight)
for k in B.nodes:
    if (k == "Beauty & Fitness"):
        nodecolor.append('blue')
    elif (k == "News"):
        nodecolor.append('Magenta')
    elif (k == "Food & Drink"):
        nodecolor.append('crimson')
    elif (k == "Health"):
        nodecolor.append('green')
    elif (k == "Science"):
        nodecolor.append('yellow')
    elif (k == "Business & Industrial"):
        nodecolor.append('cyan')
    elif (k == "Home & Garden"):
        nodecolor.append('darkorange')
    elif (k == "Travel"):
        nodecolor.append('slategrey')
    elif (k == "Arts & Entertainment"):
        nodecolor.append('red')
    elif (k == "Games"):
        nodecolor.append('grey')
    elif (k == "People & Society"):
        nodecolor.append('lightcoral')
    elif (k == "Shopping"):
        nodecolor.append('maroon')
    elif (k =="Computers & Electronics"):
        nodecolor.append('orangered')
    elif (k == "Hobbies & Leisure"):
        nodecolor.append('saddlebrown')
    elif (k == "Sports"):
        nodecolor.append('lawngreen')
    elif (k == "Real Estate"):
        nodecolor.append('deeppink')
    elif (k == "Finance"):
        nodecolor.append('navy')
    elif (k == "Reference"):
        nodecolor.append('royalblue')
    elif (k == "Autos & Vehicles"):
        nodecolor.append('turquoise')
    elif (k == "Internet & Telecom"):
        nodecolor.append('lime')
    elif (k == "Law & Government"):
        nodecolor.append('palegreen')
    elif (k == "Jobs & Education"):
        nodecolor.append('springgreen')
    elif (k == "Pets & Animals"):
        nodecolor.append('lightpink')
    elif (k == "Books & Literature"):
        nodecolor.append('lightpink')

# %%
plt.figure(figsize = (15,15))
nx.draw(B, pos=nx.circular_layout(B), node_size=1500, with_labels=True, node_color=nodecolor)
nx.draw_networkx_edge_labels(B, pos=nx.circular_layout(B), edge_labels=nx.get_edge_attributes(B, 'weight'))
plt.title('Weighted graph representing the relationship between the categories', size=20)
plt.show()

# %%
# analyse
print('Quick Review')
print (20*'...',"\n")
print("number of node : %s" % B.number_of_nodes())
print("number of arcs : %s" % B.number_of_edges())

# arc entrant
indeg = 0
for n in B.in_degree():
    indeg += n[1]

# arc sortant
outdeg = 0
for n in B.in_degree():
    outdeg += n[1]

print('')
print("the number of edges pointing to the node : %s" % indeg)
print("the number of edges pointing to the outside of the node : %s" % outdeg)

# passage en graphe non orienté
G = B.to_undirected()

# min et max de degree
listmindegre = (0, 10)
listmaxdegre = (0, 0)
for n in G.degree():
    if (listmindegre[1] > n[1]):
        listmindegre = n
    if (listmaxdegre[1] < n[1]):
        listmaxdegre = n

print('')
print("The node that has the minimal degree is : ", listmindegre)
print("The node that has the maximum degree is : ", listmaxdegre)
edgdesmax=0
for ed,w in G.edges.items():
    if(w['weight']>edgdesmax):
        edgdesmax=w['weight']
        edgdescat=ed
edgdescat
print("both category ",edgdescat[0]," and ",edgdescat[1]," has the big relationship weight( w = ",edgdesmax,")")
   
# centrality
listmincentrality = (0, 10)
listmaxcentrality = (0, 0)
for n in (nx.betweenness_centrality(G)).items():
    if (listmincentrality[1] > n[1]):
        listmincentrality = n
    elif (listmaxcentrality[1] < n[1]):
        listmaxcentrality = n

print('')
print("The node that has minimal centrality is : ", listmincentrality)
print("The node that has the maximum centrality is : ", listmaxcentrality)

# normalized
listminnormalized = (0, 10)
listmaxnormalized = (0, 0)
for n in (nx.degree_centrality(G)).items():
    if (listminnormalized[1] > n[1]):
        listminnormalized = n
    elif (listmaxnormalized[1] < n[1]):
        listmaxnormalized = n

print('')
print("The node that has the minimum (normalized) degree is : ", listminnormalized)
print("The node that has the maximal (normalized) degree is: ", listmaxnormalized)
# Out:
# Quick Review
# ............................................................
#
# number of node : 21
# number of arcs : 59
#
# the number of edges pointing to the node : 59
# the number of edges pointing to the outside of the node : 59
#
# The node that has the minimal degree is :  ('Internet & Telecom', 1)
# The node that has the maximum degree is :  ('Business & Industrial', 11)
# both category  Science  and  Pets & Animals  has the big relationship weight( w =  116 )
#
# The node that has minimal centrality is :  ('Internet & Telecom', 0.0)
# The node that has the maximum centrality is :  ('Arts & Entertainment', 0.21447472848788637)
#
# The node that has the minimum (normalized) degree is :  ('Internet & Telecom', 0.05)
# The node that has the maximal (normalized) degree is:  ('Business & Industrial', 0.55)

# %%
cl = list(nx.find_cliques(G))
print("estimate number of cliques %s" % nx.graph_number_of_cliques(G))
print("click on who has maximum number %s" % nx.graph_clique_number(G))
print('')

print(">> possible cases of clique:\n")
for cl in nx.find_cliques(G):
    if len(cl)==2 or len(cl)==3:
        print(cl)
# Out:
# estimate number of cliques 28
# click on who has maximum number 5
#
# >> possible cases of clique:
#
# ['People & Society', 'Arts & Entertainment', 'Reference']
# ['People & Society', 'Arts & Entertainment', 'Books & Literature']
# ['People & Society', 'Arts & Entertainment', 'Shopping']
# ['People & Society', 'Beauty & Fitness', 'Shopping']
# ['People & Society', 'Autos & Vehicles', 'Shopping']
# ['News', 'Computers & Electronics']
# ['News', 'Science', 'Food & Drink']
# ['Business & Industrial', 'Autos & Vehicles', 'Law & Government']
# ['Computers & Electronics', 'Internet & Telecom']
# ['Computers & Electronics', 'Games']
# ['Games', 'Arts & Entertainment']
# ['Reference', 'Hobbies & Leisure', 'Travel']
# ['Reference', 'Hobbies & Leisure', 'Arts & Entertainment']
# ['Pets & Animals', 'Science']
# ['Real Estate', 'Home & Garden']

# %%
pathlengths = []

for v in G.nodes():
    spl = nx.single_source_shortest_path_length(G, v)
    for p in spl.values():
        pathlengths.append(p)
print("average of the shortest paths %s" % round((sum(pathlengths) / len(pathlengths)), 3))

print('')

print("density : %s" % round(nx.density(G), 3))
print("diameter :", nx.diameter(G.subgraph(max(nx.connected_components(G), key=len))))

# eccentricity
listmineccentricity = (0, 10)
listmaxeccentricity = (0, 0)
for n in (nx.eccentricity(G.subgraph(max(nx.connected_components(G), key=len)))).items():
    if (listmineccentricity[1] > n[1]):
        listmineccentricity = n
    elif (listmaxeccentricity[1] < n[1]):
        listmaxeccentricity = n

print('')
print("The node that has the minimal eccentricity is : ", listmineccentricity)
print("The node that has the maximum eccentricity is : ", listmaxeccentricity)
print('')

print("center : %s" % nx.center(G.subgraph(max(nx.connected_components(G), key=len))))
print("periphery : %s" % nx.periphery(G.subgraph(max(nx.connected_components(G), key=len))))
# Out:
# average of the shortest paths 1.991
#
# density : 0.271
# diameter : 5
#
# The node that has the minimal eccentricity is :  ('Autos & Vehicles', 3)
# The node that has the maximum eccentricity is :  ('Internet & Telecom', 5)
#
# center : ['Autos & Vehicles', 'News', 'Shopping', 'Arts & Entertainment', 'Food & Drink', 'Science']
# periphery : ['Internet & Telecom', 'Real Estate']

# %%
plt.figure(figsize = (15,15))
nx.draw_random(B,  node_size=1500, with_labels=True, node_color=nodecolor)
nx.draw_networkx_edge_labels(B, pos=nx.circular_layout(B), edge_labels=nx.get_edge_attributes(B, 'weight'))
plt.title('Weighted graph representing the relationship between the categories', size=20)
plt.show()
